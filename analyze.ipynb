# %%
# %run source.ipynb
# %matplotlib inline

# %%
hft_ts_plot_meta = {
    'timestamp_column_name': 'timestamp',
    'player_id_column_name': 'player_id',
    'y_groups': [['slider_a_x', 'slider_a_y', 'slider_a_z'], 
                 ['delay'], 
                 ['bid', 'offer'], 
                 ['staged_bid', 'staged_offer'], 
                 ['inventory'], 
                 ['net_worth', 'cash'], 
                 ['signed_volume'],
                 ['best_bid', 'best_offer', 'reference_price']],
    'y_titles': ['Sensitivities', 'Message Delay (s)', 'Bid - Offer Spread ($)', 'Staged Bid-Offer Spread ($)', 
                 'Inventory Position', 'Net Worth - Cash', 'Signed Volume', 'Best Bid - Best Offer - Reference Price'],
    'y_limits': [(0, 2), (0, 0.7), (96, 106), (96, 106), (-10, 10), (0, 1500), (-12, 12), (96, 106)],
    'legend_labels': [['Signed Volume', 'Inventory', 'External Feed'], 
                      ['Delay'], 
                      ['Bid', 'Offer'], 
                      ['Staged Bid', 'Staged Offer'], 
                      ['Inventory Position'],
                      ['Net Worth', 'Cash'], 
                      ['Signed Volume'],
                      ['Best Bid', 'Best Offer', 'Reference Price']]}

# %%
SOURCE_FILENAME = 'test_input.csv'

# %%
hft_report(SOURCE_FILENAME, hft_ts_plot_meta)
# Out:
# /home/ali-demirci/environments/notebook/lib/python3.5/site-packages/ipykernel_launcher.py:29: FutureWarning: Passing timedelta64-dtype data is deprecated, will raise a TypeError in a future version
# /home/ali-demirci/environments/notebook/lib/python3.5/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
